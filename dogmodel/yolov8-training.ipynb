# %%
# install yolov8 via ultralytics
# !pip install ultralytics

# import libraries
import os
import random
import shutil
# !pip install tqdm --upgrade
from tqdm.notebook import tqdm

# connect to google drive
from google.colab import drive
drive.mount('/content/drive')

# set paths
train_img = "./yolodata/images/train/"
train_label = "./yolodata/labels/train/"
val_img = "./yolodata/images/val/"
val_label = "./yolodata/labels/val/"
test_path = "./yolodata/test/"
# Out:
# ...
# Mounted at /content/drive

# %%
def train_test_split(path,neg_path=None, split = 0.2):
    files = list(set([name[:-4] for name in os.listdir(path)])) # removing duplicates
    random.seed(42)
    random.shuffle(files)

    test_size = int(len(files) * split)
    train_size = len(files) - test_size

    os.makedirs(train_img, exist_ok = True)
    os.makedirs(train_label, exist_ok = True)
    os.makedirs(val_img, exist_ok = True)
    os.makedirs(val_label, exist_ok = True)

    # training images
    for filex in tqdm(files[:train_size]):
      if filex == 'classes':
          continue
      shutil.copy2(path + filex + '.jpg',f"{train_img}/" + filex + '.jpg' )
      shutil.copy2(path + filex + '.txt', f"{train_label}/" + filex + '.txt')

    # remove duplicate images
    if neg_path:
        neg_images = list(set([name[:-4] for name in os.listdir(neg_path)]))
        for filex in tqdm(neg_images):
            shutil.copy2(neg_path+filex+ ".jpg", f"{train_img}/" + filex + '.jpg')

    # validation images
    for filex in tqdm(files[train_size:]):
      if filex == 'classes':
          continue
      shutil.copy2(path + filex + '.jpg', f"{val_img}/" + filex + '.jpg' )
      shutil.copy2(path + filex + '.txt', f"{val_label}/" + filex + '.txt')

train_test_split('/content/drive/MyDrive/yolov8/data/')
# Out:
# ...
#   0%|          | 0/148 [00:00<?, ?it/s]

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.2/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/yolov8/data.yaml epochs=50 imgsz=640 batch=8 project=/content/drive/MyDrive/yolov8/training_results name=dog
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 215MB/s]
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/dog5/weights/best.pt conf=0.55 source=/content/drive/MyDrive/yolov8/test
# Out:
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/106 /content/drive/MyDrive/yolov8/test/063225d7d1f8c5d1_jpg.rf.dbb0f4e30176f989acce79b22e8363be.jpg: 640x640 1 dog, 16.3ms
# image 2/106 /content/drive/MyDrive/yolov8/test/081d70e9c9df0821_jpg.rf.108af2fde47dae71eae3382d1f9624f0.jpg: 640x640 1 dog, 16.3ms
# image 3/106 /content/drive/MyDrive/yolov8/test/08910577db2d0e96_jpg.rf.4a56ddeb8cc519361326f26b3ed1bdda.jpg: 640x640 (no detections), 16.3ms
# image 4/106 /content/drive/MyDrive/yolov8/test/0f33e6be3eeb9ad5_jpg.rf.8b25cee979df9ac6734f8a81ad07d222.jpg: 640x640 1 dog, 16.2ms
# image 5/106 /content/drive/MyDrive/yolov8/test/0fb027eebdc62cd3_jpg.rf.b6769281dae79000eb6af12276990f11.jpg: 640x640 3 dogs, 16.2ms
# image 6/106 /content/drive/MyDrive/yolov8/test/146c0ce4e51bd258_jpg.rf.10292d1ca53c29c4bedbe71ed08881a5.jpg: 640x640 1 dog, 16.2ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/yolov8/output

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/dog5/weights/best.pt conf=0.77 source=/content/drive/MyDrive/yolov8/videos
# Out:
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/5 (1/165) /content/drive/MyDrive/yolov8/videos/Brody the AMAZING talking dog!.mp4: 640x384 1 dog, 103.8ms
# video 1/5 (2/165) /content/drive/MyDrive/yolov8/videos/Brody the AMAZING talking dog!.mp4: 640x384 1 dog, 10.8ms
# video 1/5 (3/165) /content/drive/MyDrive/yolov8/videos/Brody the AMAZING talking dog!.mp4: 640x384 1 dog, 10.8ms
# video 1/5 (4/165) /content/drive/MyDrive/yolov8/videos/Brody the AMAZING talking dog!.mp4: 640x384 1 dog, 13.4ms
# video 1/5 (5/165) /content/drive/MyDrive/yolov8/videos/Brody the AMAZING talking dog!.mp4: 640x384 1 dog, 10.8ms
# video 1/5 (6/165) /content/drive/MyDrive/yolov8/videos/Brody the AMAZING talking dog!.mp4: 640x384 1 dog, 10.8ms
# video 1/5 (7/165) /content/drive/MyDrive/yolov8/videos/Brody the AMAZING talking dog!.mp4: 640x384 1 dog, 10.7ms
# ...

# %%
# !cp -r /content/runs/detect/predict2 /content/drive/MyDrive/yolov8/output

# %%
# !yolo mode=export model=/content/drive/MyDrive/yolov8/training_results/dog5/weights/best.pt format=onnx
# Out:
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/yolov8/training_results/dog5/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (21.5 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 62.3 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 6.9s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 8.2s, saved as '/content/drive/MyDrive/yolov8/training_results/dog5/weights/best.onnx' (42.6 MB)
#
# Export complete (11.1s)
# Results saved to /content/drive/MyDrive/yolov8/training_results/dog5/weights
# ...
